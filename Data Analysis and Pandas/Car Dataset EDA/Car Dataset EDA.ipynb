# %%
import pandas as pd

# %% [markdown]
# # Load DataSet To Pandas

# %%
df=pd.read_csv("car_sales_data_original.csv")

# %%
df
# Out:
#        Make Model        Year   Sales
# 0     acura   ILX         NaN  13.900
# 1     acura   ILX  Acura\nILX  13.414
# 2     acura   ILX        2021  14.685
# 3     acura   ILX      13.900  11.273
# 4     acura   ILX        2020  11.757
# ...     ...   ...         ...     ...
# 4038  volvo   V50         555   1.856
# 4039  volvo   V50        2010   2.850
# 4040  volvo   V50       1.720   4.138
# 4041  volvo   V50        2009   5.671
# 4042  volvo   V50       2.155   2.509
#
# [4043 rows x 4 columns]

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %% [markdown]
# # checking data is cleaned or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4043 entries, 0 to 4042
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Make    4043 non-null   object
#  1   Model   4043 non-null   object
#  2   Year    3732 non-null   object
#  3   Sales   4043 non-null   object
# dtypes: object(4)
# memory usage: 126.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(86)

# %%
df.isnull().sum()
# Out:
# Make       0
# Model      0
# Year     311
# Sales      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Make       0
# Model      0
# Year     311
# Sales      0
# dtype: int64

# %% [markdown]
# # Data is Uncleaned Now we will Cleaned it.

# %%
df
# Out:
#        Make Model        Year   Sales
# 0     acura   ILX         NaN  13.900
# 1     acura   ILX  Acura\nILX  13.414
# 2     acura   ILX        2021  14.685
# 3     acura   ILX      13.900  11.273
# 4     acura   ILX        2020  11.757
# ...     ...   ...         ...     ...
# 4038  volvo   V50         555   1.856
# 4039  volvo   V50        2010   2.850
# 4040  volvo   V50       1.720   4.138
# 4041  volvo   V50        2009   5.671
# 4042  volvo   V50       2.155   2.509
#
# [4043 rows x 4 columns]

# %%
df.drop_duplicates()
# Out:
#        Make Model        Year   Sales
# 0     acura   ILX         NaN  13.900
# 1     acura   ILX  Acura\nILX  13.414
# 2     acura   ILX        2021  14.685
# 3     acura   ILX      13.900  11.273
# 4     acura   ILX        2020  11.757
# ...     ...   ...         ...     ...
# 4038  volvo   V50         555   1.856
# 4039  volvo   V50        2010   2.850
# 4040  volvo   V50       1.720   4.138
# 4041  volvo   V50        2009   5.671
# 4042  volvo   V50       2.155   2.509
#
# [3957 rows x 4 columns]

# %%
df=df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Make       0
# Model      0
# Year     305
# Sales      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make       0
# Model      0
# Year     305
# Sales      0
# dtype: int64

# %%
df.dropna(subset=["Year"])
# Out:
#        Make Model        Year   Sales
# 1     acura   ILX  Acura\nILX  13.414
# 2     acura   ILX        2021  14.685
# 3     acura   ILX      13.900  11.273
# 4     acura   ILX        2020  11.757
# 5     acura   ILX      13.414  14.597
# ...     ...   ...         ...     ...
# 4038  volvo   V50         555   1.856
# 4039  volvo   V50        2010   2.850
# 4040  volvo   V50       1.720   4.138
# 4041  volvo   V50        2009   5.671
# 4042  volvo   V50       2.155   2.509
#
# [3652 rows x 4 columns]

# %%
df=df.dropna(subset=["Year"])

# %%
df.isnull().sum()
# Out:
# Make     0
# Model    0
# Year     0
# Sales    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3652 entries, 1 to 4042
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Make    3652 non-null   object
#  1   Model   3652 non-null   object
#  2   Year    3652 non-null   object
#  3   Sales   3652 non-null   object
# dtypes: object(4)
# memory usage: 142.7+ KB

# %%
df.describe(include="all")
# Out:
#              Make    Model  Year Sales
# count        3652     3652  3652  3652
# unique         27      303  1791  3433
# top     chevrolet  Vanagon  2020     0
# freq          481       41   116   102

# %%
df.dtypes
# Out:
# Make     object
# Model    object
# Year     object
# Sales    object
# dtype: object

# %%
df[df["Year"]=="0"]
# Out:
#             Make          Model Year   Sales
# 170        acura          Vigor    0  10.016
# 190        acura            SLX    0   1.634
# 198   alfa-romeo         Spider    0   1.102
# 209   alfa-romeo            164    0     713
# 499         audi          80/90    0   5.673
# ...          ...            ...  ...     ...
# 3781  volkswagen        Corrado    0   3.436
# 3789  volkswagen      Cabriolet    0  14.133
# 3809  volkswagen        Eurovan    0   6.673
# 3861  volkswagen  Rabbit-Pickup    0   4.861
# 3870  volkswagen   Karmann-Ghia    0  14.284
#
# [64 rows x 4 columns]

# %%
df["Year"]=pd.to_numeric(df["Year"],errors="coerce")

# %%
df
# Out:
#        Make Model      Year   Sales
# 1     acura   ILX       NaN  13.414
# 2     acura   ILX  2021.000  14.685
# 3     acura   ILX    13.900  11.273
# 4     acura   ILX  2020.000  11.757
# 5     acura   ILX    13.414  14.597
# ...     ...   ...       ...     ...
# 4038  volvo   V50   555.000   1.856
# 4039  volvo   V50  2010.000   2.850
# 4040  volvo   V50     1.720   4.138
# 4041  volvo   V50  2009.000   5.671
# 4042  volvo   V50     2.155   2.509
#
# [3652 rows x 4 columns]

# %%
df=df.dropna(subset=["Year"])

# %%
df
# Out:
#        Make Model      Year   Sales
# 2     acura   ILX  2021.000  14.685
# 3     acura   ILX    13.900  11.273
# 4     acura   ILX  2020.000  11.757
# 5     acura   ILX    13.414  14.597
# 6     acura   ILX  2019.000  18.531
# ...     ...   ...       ...     ...
# 4038  volvo   V50   555.000   1.856
# 4039  volvo   V50  2010.000   2.850
# 4040  volvo   V50     1.720   4.138
# 4041  volvo   V50  2009.000   5.671
# 4042  volvo   V50     2.155   2.509
#
# [3342 rows x 4 columns]

# %%
df["Year"]=df["Year"].astype(int)
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\195054925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"]=df["Year"].astype(int)

# %%
df
# Out:
#        Make Model  Year   Sales
# 2     acura   ILX  2021  14.685
# 3     acura   ILX    13  11.273
# 4     acura   ILX  2020  11.757
# 5     acura   ILX    13  14.597
# 6     acura   ILX  2019  18.531
# ...     ...   ...   ...     ...
# 4038  volvo   V50   555   1.856
# 4039  volvo   V50  2010   2.850
# 4040  volvo   V50     1   4.138
# 4041  volvo   V50  2009   5.671
# 4042  volvo   V50     2   2.509
#
# [3342 rows x 4 columns]

# %%
df["Year"].min()
# Out:
# 0

# %%
df["Year"].max()
# Out:
# 2021

# %%
import numpy as np

# %%
def checking(year):
    if year>=1925 and year<=2025:
        return year
    else:
        np.nan

# %%
df["Year"].apply(checking)
# Out:
# 2       2021.0
# 3          NaN
# 4       2020.0
# 5          NaN
# 6       2019.0
#          ...
# 4038       NaN
# 4039    2010.0
# 4040       NaN
# 4041    2009.0
# 4042       NaN
# Name: Year, Length: 3342, dtype: float64

# %%
df["Year"]=df["Year"].apply(checking)
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\4150042134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"]=df["Year"].apply(checking)

# %%
df
# Out:
#        Make Model    Year   Sales
# 2     acura   ILX  2021.0  14.685
# 3     acura   ILX     NaN  11.273
# 4     acura   ILX  2020.0  11.757
# 5     acura   ILX     NaN  14.597
# 6     acura   ILX  2019.0  18.531
# ...     ...   ...     ...     ...
# 4038  volvo   V50     NaN   1.856
# 4039  volvo   V50  2010.0   2.850
# 4040  volvo   V50     NaN   4.138
# 4041  volvo   V50  2009.0   5.671
# 4042  volvo   V50     NaN   2.509
#
# [3342 rows x 4 columns]

# %%
df=df.dropna(subset=["Year"])

# %%
df
# Out:
#        Make Model    Year   Sales
# 2     acura   ILX  2021.0  14.685
# 4     acura   ILX  2020.0  11.757
# 6     acura   ILX  2019.0  18.531
# 8     acura   ILX  2018.0  20.430
# 12    acura   TSX  2016.0   6.287
# ...     ...   ...     ...     ...
# 4031  volvo   S40  2008.0  18.112
# 4033  volvo   S40  2007.0  35.634
# 4037  volvo   V50  2011.0   2.155
# 4039  volvo   V50  2010.0   2.850
# 4041  volvo   V50  2009.0   5.671
#
# [1744 rows x 4 columns]

# %%
df["Year"]=df["Year"].astype(int)
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\195054925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"]=df["Year"].astype(int)

# %%
df
# Out:
#        Make Model  Year   Sales
# 2     acura   ILX  2021  14.685
# 4     acura   ILX  2020  11.757
# 6     acura   ILX  2019  18.531
# 8     acura   ILX  2018  20.430
# 12    acura   TSX  2016   6.287
# ...     ...   ...   ...     ...
# 4031  volvo   S40  2008  18.112
# 4033  volvo   S40  2007  35.634
# 4037  volvo   V50  2011   2.155
# 4039  volvo   V50  2010   2.850
# 4041  volvo   V50  2009   5.671
#
# [1744 rows x 4 columns]

# %%
df["Make"]=df["Make"].str.capitalize()
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\2415199279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Make"]=df["Make"].str.capitalize()

# %%
df
# Out:
#        Make Model  Year   Sales
# 2     Acura   ILX  2021  14.685
# 4     Acura   ILX  2020  11.757
# 6     Acura   ILX  2019  18.531
# 8     Acura   ILX  2018  20.430
# 12    Acura   TSX  2016   6.287
# ...     ...   ...   ...     ...
# 4031  Volvo   S40  2008  18.112
# 4033  Volvo   S40  2007  35.634
# 4037  Volvo   V50  2011   2.155
# 4039  Volvo   V50  2010   2.850
# 4041  Volvo   V50  2009   5.671
#
# [1744 rows x 4 columns]

# %%
df.Sales
# Out:
# 2       14.685
# 4       11.757
# 6       18.531
# 8       20.430
# 12       6.287
#          ...
# 4031    18.112
# 4033    35.634
# 4037     2.155
# 4039     2.850
# 4041     5.671
# Name: Sales, Length: 1744, dtype: object

# %%
df["Sales"]=pd.to_numeric(df["Sales"],errors="coerce")
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\187330634.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sales"]=pd.to_numeric(df["Sales"],errors="coerce")

# %%
df
# Out:
#        Make Model  Year   Sales
# 2     Acura   ILX  2021  14.685
# 4     Acura   ILX  2020  11.757
# 6     Acura   ILX  2019  18.531
# 8     Acura   ILX  2018  20.430
# 12    Acura   TSX  2016   6.287
# ...     ...   ...   ...     ...
# 4031  Volvo   S40  2008  18.112
# 4033  Volvo   S40  2007  35.634
# 4037  Volvo   V50  2011   2.155
# 4039  Volvo   V50  2010   2.850
# 4041  Volvo   V50  2009   5.671
#
# [1744 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Make     0
# Model    0
# Year     0
# Sales    4
# dtype: int64

# %%
df=df.dropna(subset=["Sales"])

# %%
df
# Out:
#        Make Model  Year   Sales
# 2     Acura   ILX  2021  14.685
# 4     Acura   ILX  2020  11.757
# 6     Acura   ILX  2019  18.531
# 8     Acura   ILX  2018  20.430
# 12    Acura   TSX  2016   6.287
# ...     ...   ...   ...     ...
# 4031  Volvo   S40  2008  18.112
# 4033  Volvo   S40  2007  35.634
# 4037  Volvo   V50  2011   2.155
# 4039  Volvo   V50  2010   2.850
# 4041  Volvo   V50  2009   5.671
#
# [1740 rows x 4 columns]

# %% [markdown]
# # feature Engineering

# %%
def currency(year):
    return "$"

# %%
df["Currency"]=df["Year"].apply(currency)
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\3382564091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Currency"]=df["Year"].apply(currency)

# %%
df
# Out:
#        Make Model  Year   Sales Currency
# 2     Acura   ILX  2021  14.685        $
# 4     Acura   ILX  2020  11.757        $
# 6     Acura   ILX  2019  18.531        $
# 8     Acura   ILX  2018  20.430        $
# 12    Acura   TSX  2016   6.287        $
# ...     ...   ...   ...     ...      ...
# 4031  Volvo   S40  2008  18.112        $
# 4033  Volvo   S40  2007  35.634        $
# 4037  Volvo   V50  2011   2.155        $
# 4039  Volvo   V50  2010   2.850        $
# 4041  Volvo   V50  2009   5.671        $
#
# [1740 rows x 5 columns]

# %%
df["Car AGE"]=2025-df["Year"]
# Out:
# C:\Users\Shah\AppData\Local\Temp\ipykernel_3812\4025044936.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Car AGE"]=2025-df["Year"]

# %%
df
# Out:
#        Make Model  Year   Sales Currency  Car AGE
# 2     Acura   ILX  2021  14.685        $        4
# 4     Acura   ILX  2020  11.757        $        5
# 6     Acura   ILX  2019  18.531        $        6
# 8     Acura   ILX  2018  20.430        $        7
# 12    Acura   TSX  2016   6.287        $        9
# ...     ...   ...   ...     ...      ...      ...
# 4031  Volvo   S40  2008  18.112        $       17
# 4033  Volvo   S40  2007  35.634        $       18
# 4037  Volvo   V50  2011   2.155        $       14
# 4039  Volvo   V50  2010   2.850        $       15
# 4041  Volvo   V50  2009   5.671        $       16
#
# [1740 rows x 6 columns]

# %% [markdown]
# # Rename Columns

# %%
df=df.rename(columns={"Make":"Brand","Car AGE": "Car Age"})

# %%
df
# Out:
#       Brand Model  Year   Sales Currency  Car Age
# 2     Acura   ILX  2021  14.685        $        4
# 4     Acura   ILX  2020  11.757        $        5
# 6     Acura   ILX  2019  18.531        $        6
# 8     Acura   ILX  2018  20.430        $        7
# 12    Acura   TSX  2016   6.287        $        9
# ...     ...   ...   ...     ...      ...      ...
# 4031  Volvo   S40  2008  18.112        $       17
# 4033  Volvo   S40  2007  35.634        $       18
# 4037  Volvo   V50  2011   2.155        $       14
# 4039  Volvo   V50  2010   2.850        $       15
# 4041  Volvo   V50  2009   5.671        $       16
#
# [1740 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1740 entries, 2 to 4041
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brand     1740 non-null   object
#  1   Model     1740 non-null   object
#  2   Year      1740 non-null   int64
#  3   Sales     1740 non-null   float64
#  4   Currency  1740 non-null   object
#  5   Car Age   1740 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 95.2+ KB

# %%
df.describe()
# Out:
#               Year        Sales      Car Age
# count  1740.000000  1740.000000  1740.000000
# mean   2009.381609    89.691294    15.618391
# std      10.318131   148.086047    10.318131
# min    1966.000000     0.000000     4.000000
# 25%    2004.000000    10.814000     7.000000
# 50%    2012.000000    33.624500    13.000000
# 75%    2018.000000    98.980750    21.000000
# max    2021.000000   993.000000    59.000000

# %%
df.describe(include="all")
# Out:
#             Brand    Model         Year        Sales Currency      Car Age
# count        1740     1740  1740.000000  1740.000000     1740  1740.000000
# unique         27      300          NaN          NaN        1          NaN
# top     Chevrolet  Mustang          NaN          NaN        $          NaN
# freq          231       20          NaN          NaN     1740          NaN
# mean          NaN      NaN  2009.381609    89.691294      NaN    15.618391
# std           NaN      NaN    10.318131   148.086047      NaN    10.318131
# min           NaN      NaN  1966.000000     0.000000      NaN     4.000000
# 25%           NaN      NaN  2004.000000    10.814000      NaN     7.000000
# 50%           NaN      NaN  2012.000000    33.624500      NaN    13.000000
# 75%           NaN      NaN  2018.000000    98.980750      NaN    21.000000
# max           NaN      NaN  2021.000000   993.000000      NaN    59.000000

# %% [markdown]
# # Groupby

# %%
grouped=df.groupby("Brand")

# %%
grouped["Sales"].agg(["sum","mean","max","min","median"])
# Out:
#                      sum        mean      max      min    median
# Brand
# Acura           7006.079   82.424459  884.000    0.000   31.1780
# Alfa-romeo      2214.896  130.288000  663.000    0.000    3.4500
# Audi           10791.276   74.939417  889.000    0.000   12.7285
# Bentley          986.000  493.000000  791.000  195.000  493.0000
# Bmw             6518.511   62.677990  970.000    0.000   10.0365
# Buick           3795.407   55.814809  602.000    0.000   41.0410
# Cadillac        4630.528   47.737402  875.000    0.000   21.4700
# Chevrolet      30474.206  131.922970  716.051    0.000   80.5670
# Chrysler        4427.566   71.412355  293.819    0.000   58.7895
# Daewoo            79.083    8.787000   18.347    0.000    9.3210
# Daihatsu          26.444    6.611000   11.460    0.000    7.4920
# Dodge          10592.672   98.080296  760.000    0.000   79.9305
# Fiat             821.278   74.661636  771.000    1.664    4.4780
# ...

# %% [markdown]
# This statistics shows company highest sales , minimum sales, avg sales, total sales etc

# %%
grouped[["Sales","Year"]].agg(["max","min"])
# Out:
#                  Sales           Year
#                    max      min   max   min
# Brand
# Acura          884.000    0.000  2021  1992
# Alfa-romeo     663.000    0.000  2021  1990
# Audi           889.000    0.000  2021  1978
# Bentley        791.000  195.000  2017  2017
# Bmw            970.000    0.000  2021  2000
# Buick          602.000    0.000  2021  1991
# Cadillac       875.000    0.000  2021  1991
# Chevrolet      716.051    0.000  2021  1988
# Chrysler       293.819    0.000  2021  1999
# Daewoo          18.347    0.000  2003  2001
# Daihatsu        11.460    0.000  1992  1991
# Dodge          760.000    0.000  2021  1989
# Fiat           771.000    1.664  2021  2018
# Ford           911.597    1.919  2021  1994
# Jeep           300.031    0.000  2021  1993
# Kia            455.000    1.425  2021  2006
# Mercedes-benz   21.897    0.000  1994  1989
# Nissan         255.601    0.000  2021  1990
# Oldsmobile     122.722    1.973  2006  2001
# ...

# %%
grouped[["Car Age"]].agg(["max","min"])
# Out:
#               Car Age
#                   max min
# Brand
# Acura              33   4
# Alfa-romeo         35   4
# Audi               47   4
# Bentley             8   8
# Bmw                25   4
# Buick              34   4
# Cadillac           34   4
# Chevrolet          37   4
# Chrysler           26   4
# Daewoo             24  22
# Daihatsu           34  33
# Dodge              36   4
# Fiat                7   4
# Ford               31   4
# Jeep               32   4
# Kia                19   4
# Mercedes-benz      36  31
# Nissan             35   4
# Oldsmobile         24  19
# Peugeot            38  31
# Plymouth           46  29
# Pontiac            34  15
# Porsche            37   4
# Saab               34  25
# Saturn             27  15
# Volkswagen         59  20
# Volvo              19   4

# %% [markdown]
# This statistical table show the branch oldest car and brand newest car

# %% [markdown]
# # Visulization

# %%
import matplotlib.pyplot as plt

# %%
a=df.sort_values(["Sales"],ascending=False)

# %%
a=a.head()

# %%
a
# Out:
#      Brand     Model  Year    Sales Currency  Car Age
# 3659  Saab      9000  2000  993.000        $       25
# 749    Bmw        Z4  2012  970.000        $       13
# 706    Bmw  8-series  2009  942.000        $       16
# 2516  Ford  F-series  2012  911.597        $       13
# 2512  Ford  F-series  2014  901.463        $       11

# %%
plt.plot(a["Year"],a["Sales"],color="red",linestyle="--")
plt.title("Comparsion between Year and Price")
plt.xlabel("Year",labelpad=10)
plt.ylabel("Price",labelpad=10)
# Out:
# Text(0, 0.5, 'Price')

# %%
grouped_sales=grouped["Sales"].max()

# %%
grouped_sales
# Out:
# Brand
# Acura            884.000
# Alfa-romeo       663.000
# Audi             889.000
# Bentley          791.000
# Bmw              970.000
# Buick            602.000
# Cadillac         875.000
# Chevrolet        716.051
# Chrysler         293.819
# Daewoo            18.347
# Daihatsu          11.460
# Dodge            760.000
# Fiat             771.000
# Ford             911.597
# Jeep             300.031
# Kia              455.000
# Mercedes-benz     21.897
# Nissan           255.601
# Oldsmobile       122.722
# Peugeot          335.000
# Plymouth         146.762
# Pontiac          234.936
# Porsche          835.000
# Saab             993.000
# Saturn           285.674
# Volkswagen       867.000
# Volvo            563.000
# Name: Sales, dtype: float64

# %%
a=grouped_sales.sort_values(ascending=False)

# %%
a=a.head()

# %%
plt.bar(a.index,a.values,color=["Red","Black"])
plt.title("Top 5 Highest Saling Brand")
plt.xlabel("Sales")
plt.ylabel("Brand")
# Out:
# Text(0, 0.5, 'Brand')

# %%
import seaborn as sns

# %%
df
# Out:
#       Brand Model  Year   Sales Currency  Car Age
# 2     Acura   ILX  2021  14.685        $        4
# 4     Acura   ILX  2020  11.757        $        5
# 6     Acura   ILX  2019  18.531        $        6
# 8     Acura   ILX  2018  20.430        $        7
# 12    Acura   TSX  2016   6.287        $        9
# ...     ...   ...   ...     ...      ...      ...
# 4031  Volvo   S40  2008  18.112        $       17
# 4033  Volvo   S40  2007  35.634        $       18
# 4037  Volvo   V50  2011   2.155        $       14
# 4039  Volvo   V50  2010   2.850        $       15
# 4041  Volvo   V50  2009   5.671        $       16
#
# [1740 rows x 6 columns]

# %%
sns.relplot(data=df,x="Year",y="Sales",hue="Brand",style="Brand",size="Car Age")
plt.title("Brand Car Sales Throught Out The Year")
plt.xlabel("Year")
plt.ylabel("Sales")
# Out:
# Text(53.731111111111105, 0.5, 'Sales')

# %%
a=df.sort_values(["Year"],ascending=False)

# %%
a=a.groupby(["Brand","Year"])

# %%
a=a["Sales"].max()

# %%
a
# Out:
# Brand  Year
# Acura  1992      0.000
#        1993     54.713
#        1994     64.638
#        1995     65.689
#        1996     38.866
#                 ...
# Volvo  2017     12.932
#        2018    563.000
#        2019     26.133
#        2020    183.000
#        2021    500.000
# Name: Sales, Length: 494, dtype: float64

# %%
df2 = a.reset_index()

# %%
a=df2.sort_values(["Year"],ascending=False)

# %%
a=a.head()

# %%
a
# Out:
#           Brand  Year    Sales
# 28        Acura  2021  238.000
# 38   Alfa-romeo  2021  144.000
# 345      Nissan  2021   72.369
# 493       Volvo  2021  500.000
# 97          Bmw  2021   70.110

# %%
sns.relplot(data=a,x="Brand",y="Sales",col="Year",hue="Brand",style="Brand")
plt.title("Top 5 famous brand sale in 2021")
# Out:
# Text(0.5, 1.0, 'Top 5 famous brand sale in 2021')

# %%
corr=df.corr(numeric_only=True)

# %%
corr
# Out:
#              Year     Sales   Car Age
# Year     1.000000  0.048777 -1.000000
# Sales    0.048777  1.000000 -0.048777
# Car Age -1.000000 -0.048777  1.000000

# %% [markdown]
# Correlation values range from -1 to +1:
#
# +1 → perfect positive relationship
#
# 0 → no relationship
#
# –1 → perfect negative relationship

# %%
sns.heatmap(corr,annot=True,cmap="viridis")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df,hue="Brand")
plt.show()

# %% [markdown]
# # Save

# %%
df.to_csv("Car Cleaned Dataset",index=False)
